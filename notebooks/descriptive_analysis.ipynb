# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/acclab_data_innovation.csv')
data[:5]
# Out:
#            Technique         Datasource                            Area  \
# 0  Feature detection      Drone imagery     Agriculture and pastoralism
# 1  Feature detection      Drone imagery     Agriculture and pastoralism
# 2  Feature detection  Satellite imagery  Pollution and waste management
# 3  Feature detection  Satellite imagery  Pollution and waste management
# 4  Feature detection  Satellite imagery  Pollution and waste management
#
#               Application         Lab  \
# 0  Crop disease detection    Cameroon
# 1  Crop disease detection  Cabo verde
# 2     Dump site detection   Guatemala
# 3     Dump site detection      Serbia
# 4     Dump site detection     Vietnam
#
#                                                 Link UNDP region  \
# 0  https://www.undp.org/cameroon/blog/will-drone-...         RBA
# 1                                                NaN         RBA
# 2                                                NaN       RBLAC
# ...

# %%
datasources = data.groupby('Technique')['Lab'].count().sort_values()
y = np.arange(len(datasources.index))
values = list(datasources.values)

plt.barh(y, values, align='center', color = '#0468b1', alpha = 0.5)
plt.yticks(y, list(datasources.index))
plt.xlabel('Count')
plt.title('Technique')

plt.show()

# %%
datasources = data.groupby('Datasource')['Lab'].count().sort_values()
y = np.arange(len(datasources.index))
values = list(datasources.values)

plt.barh(y, values, align='center', color = '#0468b1', alpha = 0.5)
plt.yticks(y, list(datasources.index))
plt.xlabel('Count')
plt.title('Datasource')

plt.show()

# %%
datasources = data.groupby('Area')['Lab'].count().sort_values()
y = np.arange(len(datasources.index))
values = list(datasources.values)

plt.barh(y, values, align='center', color = '#0468b1', alpha = 0.5)
plt.yticks(y, list(datasources.index))
plt.xlabel('Count')
plt.title('Area')

plt.show()
